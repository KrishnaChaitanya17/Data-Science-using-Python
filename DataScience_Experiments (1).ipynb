# %% [markdown]
# ## **NAME      : Y.V.KRISHNA CHAITANYA**
#
#
# # **SUBJECT : DATA SCIENCE **

# %% [markdown]
# # **Exp:1.1**
# Download the sampledata_orders.csv dataset. As the name says it is a .csv file. The file contains information regarding sales order details of United Shipping Agency. Open it in a text editor or excel and inspect it first.

# %% [markdown]
# Write a python program to load the data stored in a csv data file sampledata_orders.csv in a pandas DataFrame and perform the following operations.
# i.	Print the top 5 row and top 10 row
# ii.	Print the all column names
# iii.	Print the all row index ranges
# iv.	Print the Order Quantity column (top 5 values)
# v.	Print The Sales column (top 10 values)
# vi.	Print the row with ID:50
# vii.	Print the third row
# viii.	Print the Order Quantity, Sales, Discount and Profit of the 2nd,4th, 6th and 8th row
# ix.	Print the Order Quantity, Sales, Discount and  Profit of orders with discount > 10%
# x.print the production cost

# %% [markdown]
# i. Print the top 5 row and top 10 row

# %%
import pandas as pd
df = pd.read_csv('sampledata_orders.csv')

# %%
df.head()
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
#
# [5 rows x 21 columns]

# %%
df.head(10)
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
# 5      86       515  ...                0.37   8/30/2010
# 6      97       613  ...                0.38   6/17/2011
# 7      98       613  ...                 NaN   6/18/2011
# 8     103       643  ...                 NaN   3/25/2011
# 9     107       678  ...                0.38   2/26/2010
#
# [10 rows x 21 columns]

# %% [markdown]
# ii. Print the all column names

# %%
import pandas as pd  
data = pd.read_csv("sampledata_orders.csv")   
for col in data.columns: 
    print(col)
# Out:
# Row ID
# Order ID
# Order Date
# Order Priority
# Order Quantity
# Sales
# Discount
# Ship Mode
# Profit
# Unit Price
# Shipping Cost
# Customer Name
# Province
# Region
# Customer Segment
# Product Category
# Product Sub-Category
# Product Name
# Product Container
# Product Base Margin
# Ship Date

# %% [markdown]
# iii. Print the all row index ranges

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %% [markdown]
# iv. Print the Order Quantity column (top 5 values)

# %%
df.nlargest(5, ['Order Quantity'])
# Out:
#      Row ID  Order ID  ... Product Base Margin  Ship Date
# 46      670      4676  ...                0.37   9/2/2011
# 72     1017      7430  ...                0.38   6/9/2010
# 93     1445     10437  ...                0.37  8/20/2009
# 138    2117     15108  ...                0.36  8/29/2009
# 267    4118     29287  ...                0.39   7/4/2009
#
# [5 rows x 21 columns]

# %%
df['Order Quantity'].head()
# Out:
# 0     6
# 1    49
# 2    27
# 3    30
# 4    19
# Name: Order Quantity, dtype: int64

# %% [markdown]
# v. Print The Sales column (top 10 values)

# %%
df.nlargest(10, ['Sales'])
# Out:
#       Row ID  Order ID  ... Product Base Margin   Ship Date
# 4674    4190     29766  ...                0.39   3/22/2009
# 3512     452      3073  ...                0.39    1/8/2009
# 5861    4264     30343  ...                0.39   5/23/2012
# 3572    2026     14435  ...                0.37   12/4/2012
# 6995    4629     32932  ...                0.44   1/13/2010
# 4806    5235     37252  ...                0.62  11/24/2011
# 5646    4873     34663  ...                0.40    7/8/2011
# 1510    6852     48800  ...                0.37  10/23/2010
# 4767    2909     20967  ...                0.37   3/15/2011
# 7903    4079     29058  ...                0.62    1/5/2010
#
# [10 rows x 21 columns]

# %%
df['Sales'].head(10)
# Out:
# 0      261.5400
# 1    10123.0200
# 2      244.5700
# 3     4965.7595
# 4      394.2700
# 5      146.6900
# 6       93.5400
# 7      905.0800
# 8     2781.8200
# 9      228.4100
# Name: Sales, dtype: float64

# %% [markdown]
# vi. Print the row with ID:50

# %%
df.iloc[2,:]
# Out:
# Row ID                                                                50
# Order ID                                                             293
# Order Date                                                     10/1/2012
# Order Priority                                                      High
# Order Quantity                                                        27
# Sales                                                             244.57
# Discount                                                            0.01
# Ship Mode                                                    Regular Air
# Profit                                                             46.71
# Unit Price                                                          8.69
# Shipping Cost                                                       2.99
# Customer Name                                               Barry French
# Province                                                         Nunavut
# ...

# %%
df[df['Row ID']==50]
# Out:
#    Row ID  Order ID  ... Product Base Margin  Ship Date
# 2      50       293  ...                0.39  10/3/2012
#
# [1 rows x 21 columns]

# %% [markdown]
# vii. Print the third row

# %%
df.iloc[2]
# Out:
# Row ID                                                                50
# Order ID                                                             293
# Order Date                                                     10/1/2012
# Order Priority                                                      High
# Order Quantity                                                        27
# Sales                                                             244.57
# Discount                                                            0.01
# Ship Mode                                                    Regular Air
# Profit                                                             46.71
# Unit Price                                                          8.69
# Shipping Cost                                                       2.99
# Customer Name                                               Barry French
# Province                                                         Nunavut
# ...

# %% [markdown]
# viii. Print the Order Quantity, Sales, Discount and Profit of the 2nd,4th, 6th and 8th row

# %%
df.iloc[[1,3,5,7], [4,5,6,8]]
# Out:
#    Order Quantity       Sales  Discount   Profit
# 1              49  10123.0200      0.07   457.81
# 3              30   4965.7595      0.08  1198.97
# 5              21    146.6900      0.05     4.43
# 7              22    905.0800      0.09   127.70

# %%
df.loc[[1,3,5,7],['Order Quantity', 'Sales','Discount','Profit']]
# Out:
#    Order Quantity       Sales  Discount   Profit
# 1              49  10123.0200      0.07   457.81
# 3              30   4965.7595      0.08  1198.97
# 5              21    146.6900      0.05     4.43
# 7              22    905.0800      0.09   127.70

# %% [markdown]
# ix. Print the Order Quantity, Sales, Discount and Profit of orders with discount > 10%

# %%
df.loc[(df.Discount > 0.1), ['Order Quantity', 'Sales','Discount','Profit']]
# Out:
#       Order Quantity    Sales  Discount  Profit
# 18                11  663.784      0.25 -481.04
# 237               22  338.520      0.21  -17.75
# 1321              43  586.110      0.11   98.44
# 1383               1   27.960      0.17   -9.13
# 1454              49  651.900      0.16  -74.51

# %%
df[df['Discount']> 0.1] [['Order Quantity', 'Sales','Discount','Profit']]
# Out:
#       Order Quantity    Sales  Discount  Profit
# 18                11  663.784      0.25 -481.04
# 237               22  338.520      0.21  -17.75
# 1321              43  586.110      0.11   98.44
# 1383               1   27.960      0.17   -9.13
# 1454              49  651.900      0.16  -74.51

# %% [markdown]
# x.print the production cost

# %%
df['Sales']-df['Profit']#(production cost= Sales-Profit)
# Out:
# 0        474.7900
# 1       9665.2100
# 2        197.8600
# 3       3766.7895
# 4        363.3300
#           ...
# 8394    1617.2200
# 8395     370.3200
# 8396     480.7300
# 8397     629.0775
# 8398    1445.5800
# Length: 8399, dtype: float64

# %% [markdown]
# # **EX :1.2**

# %% [markdown]
#  Download the train.csv dataset. As the name says it is a .csv file. The file contains information regarding loans given or refused to applicants. Information on the gender, marital status, education, work and income of the applicant is reported alongside the amount and length of the loan and credit history (i.e. 0 if no previous loan was given, 1 otherwise). Open it in a text editor or excel and inspect it first. Then, answer the following questions (if you have any doubts check here): Load it into a pandas DataFrame. (use column Loan_ID as index. Hint: use parm index_col).

# %% [markdown]
# i.Get an idea of the data by visualizing its first 5 entries;
#
# ii.How many total entries are present in the file and How many column are there in the file? How many males and females?
#
# iii.What is the average applicant income? How many Females have an income > than the average?
#
# iv.How many loans have been given (i.e. Loan_Status equals Y)? What is the percentage of the loans given and that of the loans refused?
#
# v.What is the percentage of given/refused loans in the case of married people?
#
# vi.What is the percentage of given/refused loans in the case of applicants with positive credit history (i.e. Credit_History equals 1)?

# %%
import pandas as pd
df=pd.read_csv('train.csv')

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# i.Get an idea of the data by visualizing its first 5 entries

# %%
df.head()
# Out:
#     Loan_ID Gender Married  ... Credit_History Property_Area Loan_Status
# 0  LP001002   Male      No  ...            1.0         Urban           Y
# 1  LP001003   Male     Yes  ...            1.0         Rural           N
# 2  LP001005   Male     Yes  ...            1.0         Urban           Y
# 3  LP001006   Male     Yes  ...            1.0         Urban           Y
# 4  LP001008   Male      No  ...            1.0         Urban           Y
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 609  LP002978  Female      No  ...            1.0         Rural           Y
# 610  LP002979    Male     Yes  ...            1.0         Rural           Y
# 611  LP002983    Male     Yes  ...            1.0         Urban           Y
# 612  LP002984    Male     Yes  ...            1.0         Urban           Y
# 613  LP002990  Female      No  ...            0.0     Semiurban           N
#
# [5 rows x 13 columns]

# %% [markdown]
# ii.How many total entries are present in the file and How many column are there in the file? How many males and females?

# %%
len(df.index)
# Out:
# 614

# %%
df.shape[0]
# Out:
# 614

# %%
len(df.columns)
# Out:
# 13

# %%
df.shape[1]
# Out:
# 13

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %% [markdown]
# iii.What is the average applicant income? How many Females have an income > than the average?

# %%
df['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
len(df.loc[(df['Gender']=='Female') & (df['ApplicantIncome']>df['ApplicantIncome'].mean())])
# Out:
# 21

# %% [markdown]
# iv.How many loans have been given (i.e. Loan_Status equals Y)? What is the percentage of the loans given and that of the loans refused?

# %%
y=len(df[df['Loan_Status']=='Y'])
print(y)
# Out:
# 422

# %%
df['Loan_Status'].value_counts()[0]
# Out:
# 422

# %%
n=len(df[df['Loan_Status']=='N'])
print(y/len(df['Loan_Status'])*100)
print(n/len(df['Loan_Status'])*100)
# Out:
# 68.72964169381108
# 31.27035830618892

# %% [markdown]
# v.What is the percentage of given/refused loans in the case of married people?

# %%
given=len(df.loc[(df['Loan_Status']=='Y') & (df['Married']=='Yes')])
refused=len(df.loc[(df['Loan_Status']=='N') & (df['Married']=='Yes')])
print("Percentage of given loans in case of married people is ",(given/len(df)*100))
print("Percentage of refused loans in case of married people is ",(refused/len(df)*100))
# Out:
# Percentage of given loans in case of married people is  46.416938110749186
# Percentage of refused loans in case of married people is  18.403908794788272

# %%
mard=df[df['Married']=='Yes']
mardloan=len(mard[mard['Loan_Status']=='Y'])
perc=mardloan/len(mard)*100
print('percentage o floan given for married people is',perc)
# Out:
# percentage o floan given for married people is 71.60804020100502

# %% [markdown]
# vi.What is the percentage of given/refused loans in the case of applicants with positive credit history (i.e. Credit_History equals 1)?

# %%
given=len(df.loc[(df['Loan_Status']=='Y') & (df['Credit_History']==1)])
refused=len(df.loc[(df['Loan_Status']=='N') & (df['Credit_History']==1)])
print("Percentage of given loans in case of applicants with positive credit history is ",(given/len(df)*100))
print("Percentage of refused loans in case of applicants with positive credit history is ",(refused/len(df)*100))
# Out:
# Percentage of given loans in case of applicants with positive credit history is  61.563517915309454
# Percentage of refused loans in case of applicants with positive credit history is  15.798045602605862

# %%
lost=len(df[df['Loan_Status']=='Y'])
print(lost)
perc=lost/len(df[df['Credit_History']==1])*100
print("Percentage of given loans in case of applicants with positive credit history is ",perc)
# Out:
# 422
# Percentage of given loans in case of applicants with positive credit history is  88.8421052631579

# %% [markdown]
# # **EXP : 1.3**

# %% [markdown]
# # 3.Download the diamonds.csv dataset. As the name says it is a .csv file. The file contains information regarding diamonds details of Laisha diamond shop. Open it in a text editor or excel and inspect it first. Write a python program to load the data stored in a csv file diamonds.csv in a pandas DataFrame and perform the following operations.
#
# I. find carat weight at least 0.3 and write this detail into cart.csv file
#
# II. find total price of cart weight at maximum 0.3
#
# III. Sort the ‘carat’ column by ascending and descending order.
#
# IV. Print the premium diamond details
#
# V. Find the most expensive diamond whose color is D

# %%
import pandas as pd
df=pd.read_csv("diamonds.csv")

# %% [markdown]
# I. find carat weight at least 0.3 and write this detail into cart.csv file

# %%
cart=df[df['carat']>=0.3]
cart.to_csv('cart.csv',index=False)
cart
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 10      0.30       Good     J     SI1   64.0   55.0    339  4.25  4.28  2.73
# 13      0.31      Ideal     J     SI2   62.2   54.0    344  4.35  4.37  2.71
# 15      0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# 16      0.30      Ideal     I     SI2   62.0   54.0    348  4.31  4.34  2.68
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [52341 rows x 10 columns]

# %% [markdown]
# II. find total price of cart weight at maximum 0.3

# %%
cart['price'][cart['carat']<=0.3].sum()
# Out:
# 1771506

# %% [markdown]
# III. Sort the ‘carat’ column by ascending and descending order.

# %%
df.sort_values(by=['carat'],ascending=True)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 31593   0.20  Premium     E     VS2   61.1   59.0    367   3.81   3.78  2.32
# 31597   0.20    Ideal     D     VS2   61.5   57.0    367   3.81   3.77  2.33
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
# 31595   0.20    Ideal     E     VS2   59.7   55.0    367   3.86   3.84  2.30
# 31594   0.20  Premium     E     VS2   59.7   62.0    367   3.84   3.80  2.28
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
#
# [53940 rows x 10 columns]

# %%
df.sort_values(by=['carat'],ascending=False)
# Out:
#        carat      cut color clarity  depth  table  price      x      y     z
# 27415   5.01     Fair     J      I1   65.5   59.0  18018  10.74  10.54  6.98
# 27630   4.50     Fair     J      I1   65.8   58.0  18531  10.23  10.16  6.72
# 27130   4.13     Fair     H      I1   64.8   61.0  17329  10.00   9.85  6.43
# 25999   4.01  Premium     J      I1   62.5   62.0  15223  10.02   9.94  6.24
# 25998   4.01  Premium     I      I1   61.0   61.0  15223  10.14  10.10  6.17
# ...      ...      ...   ...     ...    ...    ...    ...    ...    ...   ...
# 31592   0.20  Premium     E     VS2   59.0   60.0    367   3.81   3.78  2.24
# 31591   0.20  Premium     E     VS2   59.8   62.0    367   3.79   3.77  2.26
# 31601   0.20  Premium     D     VS2   61.7   60.0    367   3.77   3.72  2.31
# 14      0.20  Premium     E     SI2   60.2   62.0    345   3.79   3.75  2.27
# 31596   0.20  Premium     F     VS2   62.6   59.0    367   3.73   3.71  2.33
#
# [53940 rows x 10 columns]

# %% [markdown]
# IV. Print the premium diamond details

# %%
df[df['cut']=='Premium']
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1       0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3       0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 12      0.22  Premium     F     SI1   60.4   61.0    342  3.88  3.84  2.33
# 14      0.20  Premium     E     SI2   60.2   62.0    345  3.79  3.75  2.27
# 15      0.32  Premium     E      I1   60.9   58.0    345  4.38  4.42  2.68
# ...      ...      ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53928   0.79  Premium     E     SI2   61.4   58.0   2756  6.03  5.96  3.68
# 53930   0.71  Premium     E     SI1   60.5   55.0   2756  5.79  5.74  3.49
# 53931   0.71  Premium     F     SI1   59.8   62.0   2756  5.74  5.73  3.43
# 53934   0.72  Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 53938   0.86  Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
#
# [13791 rows x 10 columns]

# %% [markdown]
# V. Find the most expensive diamond whose color is D

# %%
c=df[df['color']=='D']
c['price'].max()
# Out:
# 18693

# %%
gdf1=df.groupby('color')
dgroup=gdf1.get_group('D')
dgroup['price'].max()
# Out:
# 18693

# %% [markdown]
# # EXP **2**

# %% [markdown]
# #2.1  Write a python program to read a sampledata_orders.csv file which is uploaded in the editch and perform descriptive statics and print the result.

# %%
import pandas as pd
orders=pd.read_csv("sampledata_orders.csv")

# %%
orders.head()
# Out:
#    Row ID  Order ID  ... Product Base Margin   Ship Date
# 0       1         3  ...                0.80  10/20/2010
# 1      49       293  ...                0.58   10/2/2012
# 2      50       293  ...                0.39   10/3/2012
# 3      80       483  ...                0.58   7/12/2011
# 4      85       515  ...                0.50   8/30/2010
#
# [5 rows x 21 columns]

# %%
orders.describe()
# Out:
#             Row ID      Order ID  ...  Shipping Cost  Product Base Margin
# count  8399.000000   8399.000000  ...    8399.000000          8336.000000
# mean   4200.000000  29965.179783  ...      12.838557             0.512513
# std    2424.726789  17260.883447  ...      17.264052             0.135589
# min       1.000000      3.000000  ...       0.490000             0.350000
# 25%    2100.500000  15011.500000  ...       3.300000             0.380000
# 50%    4200.000000  29857.000000  ...       6.070000             0.520000
# 75%    6299.500000  44596.000000  ...      13.990000             0.590000
# max    8399.000000  59973.000000  ...     164.730000             0.850000
#
# [8 rows x 9 columns]

# %%
orders.max()
# Out:
# Row ID                                          8399
# Order ID                                       59973
# Order Date                                  9/9/2012
# Order Priority                         Not Specified
# Order Quantity                                    50
# Sales                                        89061.1
# Discount                                        0.25
# Ship Mode                                Regular Air
# Profit                                       27220.7
# Unit Price                                   6783.02
# Shipping Cost                                 164.73
# Customer Name                         Yoseph Carroll
# Province                                       Yukon
# Region                                         Yukon
# Customer Segment                      Small Business
# Product Category                          Technology
# Product Sub-Category    Telephones and Communication
# Product Name                                iDENi80s
# ...

# %%
orders.min()
# Out:
# Row ID                                                                  1
# Order ID                                                                3
# Order Date                                                       1/1/2009
# Order Priority                                                   Critical
# Order Quantity                                                          1
# Sales                                                                2.24
# Discount                                                                0
# Ship Mode                                                  Delivery Truck
# Profit                                                           -14140.7
# Unit Price                                                           0.99
# Shipping Cost                                                        0.49
# Customer Name                                               Aaron Bergman
# Province                                                          Alberta
# ...

# %%
orders.mean()
# Out:
# Row ID                  4200.000000
# Order ID               29965.179783
# Order Quantity            25.571735
# Sales                   1775.878179
# Discount                   0.049671
# Profit                   181.184423
# Unit Price                89.346259
# Shipping Cost             12.838557
# Product Base Margin        0.512513
# dtype: float64

# %%
orders.median()
# Out:
# Row ID                  4200.00
# Order ID               29857.00
# Order Quantity            26.00
# Sales                    449.42
# Discount                   0.05
# Profit                    -1.50
# Unit Price                20.99
# Shipping Cost              6.07
# Product Base Margin        0.52
# dtype: float64

# %%
orders.var()
# Out:
# Row ID                 5.879300e+06
# Order ID               2.979381e+08
# Order Quantity         2.097014e+02
# Sales                  1.285259e+07
# Discount               1.012705e-03
# Profit                 1.431979e+06
# Unit Price             8.430567e+04
# Shipping Cost          2.980475e+02
# Product Base Margin    1.838436e-02
# dtype: float64

# %%
orders.std()
# Out:
# Row ID                  2424.726789
# Order ID               17260.883447
# Order Quantity            14.481071
# Sales                   3585.050525
# Discount                   0.031823
# Profit                  1196.653372
# Unit Price               290.354383
# Shipping Cost             17.264052
# Product Base Margin        0.135589
# dtype: float64

# %%
#rank,skew,kurtosis
df = pd.DataFrame(data={'Animal': ['cat', 'penguin', 'dog','spider', 'Snake'],
                        'Number_legs': [4, 2, 4, 8, 10],'date':['12/2/21','11/1/21','16/12/20','2/3/20','21/5/21']})
df
# Out:
#     Animal  Number_legs      date
# 0      cat            4   12/2/21
# 1  penguin            2   11/1/21
# 2      dog            4  16/12/20
# 3   spider            8    2/3/20
# 4    Snake           10   21/5/21

# %%
df['default_rank']=df['Animal'].rank()#method='min'
df.sort_values('Animal')
# Out:
#     Animal  Number_legs      date  default_rank
# 4    Snake           10   21/5/21           1.0
# 0      cat            4   12/2/21           2.0
# 2      dog            4  16/12/20           3.0
# 1  penguin            2   11/1/21           4.0
# 3   spider            8    2/3/20           5.0

# %%
orders.rank()
# Out:
#       Row ID  Order ID  ...  Product Base Margin  Ship Date
# 0        1.0       1.0  ...               8063.5      964.5
# 1       49.0      49.5  ...               5760.0      952.0
# 2       50.0      49.5  ...               2570.5     1202.5
# 3       80.0      80.0  ...               5760.0     6339.5
# 4       85.0      85.5  ...               3975.0     7490.0
# ...      ...       ...  ...                  ...        ...
# 8394  7765.0    7765.5  ...               7074.5     7668.5
# 8395  7766.0    7765.5  ...               1990.5     7013.5
# 8396  7906.0    7907.0  ...               3268.5     4208.5
# 8397  7907.0    7907.0  ...               4878.0     4841.0
# 8398  7914.0    7914.0  ...               7074.5     2865.5
#
# [8399 rows x 21 columns]

# %%
orders.skew()
# Out:
# Row ID                  0.000000
# Order ID                0.003811
# Order Quantity         -0.017318
# Sales                   5.386982
# Discount                0.073917
# Profit                  3.647239
# Unit Price             14.127793
# Shipping Cost           2.553801
# Product Base Margin     0.559400
# dtype: float64

# %%
orders.kurt()
# Out:
# Row ID                  -1.200000
# Order ID                -1.178317
# Order Quantity          -1.208020
# Sales                   60.928376
# Discount                -0.959411
# Profit                  67.349705
# Unit Price             271.168733
# Shipping Cost            7.751587
# Product Base Margin     -0.660870
# dtype: float64

# %% [markdown]
# # 2.2 Write a python program to read a sampledata_orders.csv file which is uploaded in the editch and perform descriptive statics for the first 25 rows of the sales column and print the result.

# %%
orders['Sales'].head(25)
# Out:
# 0       261.5400
# 1     10123.0200
# 2       244.5700
# 3      4965.7595
# 4       394.2700
# 5       146.6900
# 6        93.5400
# 7       905.0800
# 8      2781.8200
# 9       228.4100
# 10      196.8500
# 11      124.5600
# 12      716.8400
# 13     1474.3300
# 14       80.6100
# 15     1815.4900
# 16      248.2600
# 17     4462.2300
# 18      663.7840
# 19      834.9040
# 20     2480.9205
# 21       59.0300
# 22       97.4800
# 23      511.8300
# 24      184.9900
# Name: Sales, dtype: float64

# %%
orders['Sales'].head(25).max()
# Out:
# 10123.02

# %%
orders['Sales'].head(25).min()
# Out:
# 59.03

# %%
orders['Sales'].head(25).mean()
# Out:
# 1363.8723200000002

# %%
orders['Sales'].head(25).median()
# Out:
# 394.27

# %%
orders['Sales'].head(25).std()
# Out:
# 2265.4435735954476

# %%
orders['Sales'].head(25).var()
# Out:
# 5132234.585144913

# %%
orders['Sales'].head(25).rank()
# Out:
# 0     12.0
# 1     25.0
# 2     10.0
# 3     24.0
# 4     13.0
# 5      6.0
# 6      3.0
# 7     18.0
# 8     22.0
# 9      9.0
# 10     8.0
# 11     5.0
# 12    16.0
# 13    19.0
# 14     2.0
# 15    20.0
# 16    11.0
# 17    23.0
# 18    15.0
# 19    17.0
# 20    21.0
# 21     1.0
# 22     4.0
# 23    14.0
# 24     7.0
# Name: Sales, dtype: float64

# %%
orders['Sales'].head(25).skew()
# Out:
# 2.8416355985151482

# %%
orders['Sales'].head(25).kurt()
# Out:
# 9.142791153369425

# %% [markdown]
# # 2.3 Write a python program to read a sampledata_orders.csv file which is uploaded in the editch and extract first 25 row of sampledata_orders.csv file and compute the mean of sales column. Assume null hypothesis sales mean is 1360 and perform the one sample t-test.

# %%
from scipy.stats import ttest_1samp
data=orders[0:25:1][["Sales"]]
data
# Out:
#          Sales
# 0     261.5400
# 1   10123.0200
# 2     244.5700
# 3    4965.7595
# 4     394.2700
# 5     146.6900
# 6      93.5400
# 7     905.0800
# 8    2781.8200
# 9     228.4100
# 10    196.8500
# 11    124.5600
# 12    716.8400
# 13   1474.3300
# 14     80.6100
# 15   1815.4900
# 16    248.2600
# 17   4462.2300
# 18    663.7840
# 19    834.9040
# 20   2480.9205
# 21     59.0300
# 22     97.4800
# 23    511.8300
# 24    184.9900

# %%
sales_mean=data.mean()
print(sales_mean)
tset,pval=ttest_1samp(data, 1360)
print("p-value",pval)

if pval < 0.05:
  print("we are rejecting null hypothesis")
else:
  print("we are accepting nulll hypothesis")
# Out:
# Sales    1363.87232
# dtype: float64
# p-value [0.99325161]
# we are accepting nulll hypothesis

# %% [markdown]
# # 2.4.Write a python program to read a Blood_Pressure.csv file which is uploaded in the editch and perform the  Paired sampled t-test (blood pressure for an individual before and after some treatment)
#
# # H0:- means difference between two sample is 0
#
# # H1:- mean difference between two sample is not 0

# %%
df=pd.read_csv("Blood_Pressure.csv")
df
# Out:
#      patient     sex agegrp  bp_before  bp_after
# 0          1    Male  30-45        143       153
# 1          2    Male  30-45        163       170
# 2          3    Male  30-45        153       168
# 3          4    Male  30-45        153       142
# 4          5    Male  30-45        146       141
# ..       ...     ...    ...        ...       ...
# 115      116  Female    60+        152       152
# 116      117  Female    60+        161       152
# 117      118  Female    60+        165       174
# 118      119  Female    60+        149       151
# 119      120  Female    60+        185       163
#
# [120 rows x 5 columns]

# %%
from scipy.stats import ttest_rel
ttest,pval=ttest_rel(df['bp_before'],df['bp_after'])
print(pval)#alpha-5%
if pval<0.05:
  print("reject null hypothesis")
else:
  print("we fail to reject hypothesis")
# Out:
# 0.0011297914644840823
# reject null hypothesis

# %% [markdown]
# # 2.5 Write a python program to read a Blood_Pressure.csv file which is uploaded in the editch and perform the one-sample Z test.

# %%
from statsmodels.stats import weightstats as stests
ztest,pval = stests.ztest(df['bp_before'],x2=None,value=156)
print(float(pval))
if pval<0.05:
  print("reject null hypothesis")
else:
  print("fail to reject null hypoothesis")
# Out:
# 0.6651614730255063
# fail to reject null hypoothesis

# %% [markdown]
# # 2.6 Write a python program to read a Blood_Pressure.csv file which is uploaded in the editch and perform the Two-sample Z test. (blood pressure for an individual before and after some treatment)
#
#
# # H0: mean of two group is 0
#
# # H1: mean of two group is not 0

# %%
ztest,pval2=stests.ztest(df['bp_before'],x2=df['bp_after'],value=0,alternative='two-sided')
print(float(pval2))
if pval2<0.05:
  print("reject null hypothesis")
else:
  print("fail to reject null hypothesis")
# Out:
# 0.002162306611369422
# reject null hypothesis

# %% [markdown]
# # **EXP 3**

# %% [markdown]
# # 3.1.Write a python program to perform the following operations i. Import the Matplotlib Library ii. Declare two variable x1=[1,2,3,4] and y1=[2,1,3,2]. iii. Set the x label as “x axis” iv. Set the ylabel as “y axis” v. Set the title of the plot as “Simple Line Plot” vi. Plot the graph vii. Declare two variable x2=[1,2,3,4] and y2=[2,1,3,2] viii. Plot the values of x1 and y1, x2 and y2 in the same graph. For x1, y1 : Use Red color normal lines and * Markers For X2, Y2, Use Green Color dashed line and ^ Markers

# %%
import matplotlib.pyplot as plt
x1=[1,2,3,4]
y1=[2,1,3,2]
plt.plot(x1,y1,color='r',marker='*')
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("Sample Line plot")
x2=[4,3,6,7]
y2=[2,1,3,2]
plt.plot(x2,y2,'^g-.')#marker=^,color=green,linestyle=-.
plt.show()

# %% [markdown]
# # 3.2. Write a python program to plot the square,square root, exponential and log functions using a 2 x 2 subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
f=plt.figure()
x=np.arange(1,5)
plt.subplot(2,2,1)
plt.plot(x,x*x)
plt.title('square')
plt.subplot(2,2,2)
plt.plot(x,np.sqrt(x))
plt.title('square root')
plt.subplot(2,2,3)
plt.plot(x,np.exp(x))
plt.title('exponnetial')
plt.subplot(2,2,4)
plt.plot(x,np.log(x))
plt.title('log')
f.subplots_adjust(hspace=1)

# %%
import matplotlib.pyplot as plt
fig,ax =  plt.subplots(2,2) # 4 subplots
import numpy as np
x = np.arange(1,5)
ax[0][0].plot(x,x*x) # plot1
ax[0][0].set_title('square')
ax[0][1].plot(x,np.sqrt(x))  # plot 2
ax[0][1].set_title('square root')
ax[1][0].plot(x,np.exp(x)) # plot3
ax[1][1].set_title('exponentail')
ax[1][1].plot(x,np.log10(x)) # plot4
ax[1][1].set_title('log')
fig.suptitle('4 equations')
plt.show()

# %% [markdown]
# # 3.3.Write a Python Program to read the orders dataset and plot a bar graph between the Order Quantity and Shipping Cost parameters

# %%
import pandas as pd
orders=pd.read_csv("sampledata_orders.csv")
orders.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
plt.bar(orders['Order Quantity'],orders['Shipping Cost'])
# Out:
# <BarContainer object of 8399 artists>

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(orders['Order Quantity'],orders['Shipping Cost'],color='m')
plt.xlabel('Order quantity')
plt.ylabel('Shipping Cost')
plt.show()

# %% [markdown]
# # 3.4. For the orders dataset plot the Order Quantity Vs Sales( do ti with figure and ax method)

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.bar(orders['Order Quantity'],orders['Sales'],color='y')
plt.xlabel('Order quantity')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # 3.5. Visualize the Order Priority series using a Histogram. Set the Bin Size to 10

# %%
plt.hist(orders['Order Priority'], bins=10)
# Out:
# (array([1720.,    0., 1768.,    0.,    0., 1672.,    0., 1631.,    0.,
#         1608.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # 3.6.Visualize Product Base Margin and Sales using a scatter plot. Set the Color to Red

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(orders['Product Base Margin'],orders['Sales'], color='r')
plt.xlabel('Product Base Margin')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# # 3.7.Load the Iris dataset and plot the petal length using a distance plott as a Histogram using seaborn

# %%
import seaborn as sb
df=sb.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sb.distplot(df['petal_length'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.distplot(df['petal_length'],kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sb.histplot(df['petal_length'])

# %%
sb.histplot(df['petal_length'],kde=True)

# %% [markdown]
# # 3.8.Load the Iris dataset and plot the petal length and petal width using a distance plot as a Line Plot using seabron

# %%
sb.lineplot(df['petal_length'],df['petal_width'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.lineplot(df['sepal_length'],df['sepal_width'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 3.9.Plot the Petal Length and Petal Width using a joint plot using seaborn

# %%
sb.jointplot(df["petal_length"], df["petal_width"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sb.jointplot(df["sepal_length"], df["sepal_width"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # 3.10.Plot the species using Pair plot

# %%
sb.pairplot(df,palette='husl')#hue='species',kind='scatter'

# %%
sb.pairplot(df,hue='species',palette='husl')

# %%
sb.pairplot(df,hue='species')

# %% [markdown]
# # 3.11.Plot the species and Petal Length using Strip Plot

# %%
sb.stripplot(x="species",y="petal_length",jitter=0.4,data=df)

# %% [markdown]
# # 3.12.Plot the species and Petal Length using Swarm Plot

# %%
sb.swarmplot(x="species",y="petal_length",data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # **EXP 4**

# %% [markdown]
# # 4.1.Generate the 10000 random numbers using normal distribution mean=0 and variance =1,(use norm.rvs function) and plot the normal distributions using seaborn

# %%
import numpy as np
import seaborn as sns
from scipy.stats import norm
#np.random.seed(42)
data_normal=norm.rvs(size=10000,loc=0,scale=1)#size,loc-mean,scale-variance

ax=sns.distplot(data_normal,bins=100,kde=True,color='skyblue',hist_kws={"linewidth":1,'alpha':1})
ax.set(xlabel='Normal',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal')]

# %%
import numpy as np
import seaborn as sns
from scipy.stats import norm
np.random.seed(42)
data_normal=norm.rvs(size=10000,loc=0,scale=1)#size,loc-mean,scale-variance

ax=sns.distplot(data_normal,bins=100,kde=False,color='skyblue',hist_kws={"linewidth":1,'alpha':1})
ax.set(xlabel='Normal',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Normal')]

# %% [markdown]
# # 4.2.Generate 10000,bernouli random numbers with success probability p=0.3,(use bernouli.rvs(size=10000,p=0.3)). and plot the bernouli disstribution using seaborn

# %%
from scipy.stats import bernoulli
data_bern=bernoulli.rvs(size=10000,p=0.3)

ax=sns.distplot(data_bern,kde=False,color='skyblue',hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='Bernoulli',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Bernoulli')]

# %% [markdown]
# # 4.3.Generate 10000,binominal random numbers with success probability p=0.3,(use bernouli.rvs(size=10000,p=0.3)). and plot the binorminal distribution using seaborn

# %%
from scipy.stats import binom
data_binom=binom.rvs(n=10,size=10000,p=0.3)

ax=sns.distplot(data_binom,kde=False,color='skyblue',hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='Binominal',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Binominal')]

# %% [markdown]
# # 4.4.Generate 10000 random numbers from poisson random variable with mu=3 and plot them

# %%
from scipy.stats import poisson
data_poisson=poisson.rvs(mu=3,size=10000)

ax=sns.distplot(data_poisson,kde=False,color='green',hist_kws={"linewidth":15,'alpha':1})
ax.set(xlabel='poisson',ylabel='Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'poisson')]

# %% [markdown]
# # **EXP-5**

# %% [markdown]
# # **BOKEH**

# %%
from bokeh.plotting import figure,output_notebook,show,output_file

# %% [markdown]
# circle plot

# %%
fig=figure(plot_width=400,plot_height=400,title='circle plot')
x=[1,2,3]
y=[1,8,27]
fig.circle(x,y,size=8)
output_notebook()
output_file('circlegraph.html')
show(fig)
# Out:
#   <div class="bk-root" id="feba3af7-1e4b-42fd-bdeb-85b3c74f8cac" data-root-id="1184"></div>

# %% [markdown]
# line plot

# %%
fig=figure(plot_width=400,plot_height=400)
x=[1,2,3]
y=[3,0,5]
fig.line(x,y,line_width=2,color='orange')
show(fig)
# Out:
#   <div class="bk-root" id="e2268f38-09bb-4a35-a768-19e49261aa0b" data-root-id="1424"></div>

# %% [markdown]
# diamond plot

# %%
fig = figure(plot_width=400, plot_height=400, title='circle plot')
x = [1, 2, 3]
y = [1, 8, 27]
fig.diamond(x,y,size=12) # cicle, square, triangle, diamond
output_notebook()
output_file('circlegraph.html')
show(fig)
# Out:
#   <div class="bk-root" id="8fe24bd8-fe64-4315-bd05-5a5aa3fb0a9a" data-root-id="1657"></div>

# %% [markdown]
# using boken with pandas

# %%
import pandas as pd
data = pd.read_csv('menu.csv')

# %%
data
# Out:
#                Category  ... Iron (% Daily Value)
# 0             Breakfast  ...                   15
# 1             Breakfast  ...                    8
# 2             Breakfast  ...                   10
# 3             Breakfast  ...                   15
# 4             Breakfast  ...                   10
# ..                  ...  ...                  ...
# 255  Smoothies & Shakes  ...                    8
# 256  Smoothies & Shakes  ...                   10
# 257  Smoothies & Shakes  ...                    6
# 258  Smoothies & Shakes  ...                    6
# 259  Smoothies & Shakes  ...                    4
#
# [260 rows x 24 columns]

# %%
from bokeh.models import ColumnDataSource

# %%
cds = ColumnDataSource(data.head()) # mapping betwn column names and values

# %%
fig = figure(plot_width=400, plot_height=400)

fig.line(x='Calories', y='Saturated Fat', source = cds)
output_notebook()
show(fig)
# Out:
#   <div class="bk-root" id="76100094-f33c-4f8c-a74f-320b31440538" data-root-id="1003"></div>

# %% [markdown]
# **multiple graph in single figure**

# %%
x_square = [20, 5, 15, 4]
y_square = [4, 10, 3, 17]
x_circle = [16, 8, 24, 4]
y_circle = [5, 10, 15, 20]
p=figure(plot_height=400,plot_width=400)
p.circle(x=x_circle,y=y_circle,size=12,color='green')
p.square(x=x_square, y=y_square, size=12, color='red')
p.diamond(x=[20,30], y=[10,15], size=12, color='blue')
show(p)
# Out:
#   <div class="bk-root" id="65e0bb85-b9d3-45cb-9700-5176c6d1e9e5" data-root-id="1102"></div>

# %% [markdown]
# BAR graph Plot a bar graph with Total Fatin x axis and calories in y axis

# %%
fig = figure(plot_width = 400, plot_height = 200, title='Bar chart')
fig.hbar(y = 'Calories', height = 5, left = 0, right = 'Total Fat', color = "Cyan", source=cds) # left, right x axis
output_file('bar.html')
show(fig)
# Out:
#   <div class="bk-root" id="a46bc5ef-5c6c-4024-ad66-194386020f41" data-root-id="2481"></div>

# %%
fig = figure(plot_width = 400, plot_height = 400)
fig.vbar(x ='Calories', width = 5, bottom = 0, top ='Total Fat', color = "Cyan", source=cds) # y axis- bottm, top
output_file('bar.html') 
show(fig)
# Out:
#   <div class="bk-root" id="c26e74fc-a880-4072-b5b9-ba8b0cf8bf27" data-root-id="4256"></div>

# %% [markdown]
# **STYLING**

# %%
fig = figure(plot_width=400, plot_height=400)

fig.line(x='Calories', y='Saturated Fat', source = cds)
output_notebook()
fig.outline_line_color = 'red' 
fig.outline_line_width = 3
fig.outline_line_alpha = 0.4
show(fig)
# Out:
#   <div class="bk-root" id="60c77e55-7efe-4b30-9551-b5f59dc5ed7e" data-root-id="1248"></div>

# %% [markdown]
# x-axis and y-axis

# %%
p = figure(plot_width=400, plot_height=400)

p.line(x='Calories', y='Saturated Fat', source = cds)
output_notebook()

p.xaxis.axis_line_color = 'purple'
p.xaxis.axis_line_width = 2
p.xaxis.axis_line_alpha=1

p.yaxis.axis_line_color = 'blue'
p.yaxis.axis_line_width = 2
p.yaxis.axis_line_alpha=0.5

show(p)
# Out:
#   <div class="bk-root" id="a02b4c4d-88ca-4464-80c9-7b61f9a1dd5c" data-root-id="1369"></div>

# %% [markdown]
# **set title, axis name**

# %%
p = figure(plot_width=400, plot_height=400, title='line graph',y_axis_label='Y axis', x_axis_label='X axis')
p.line(x='Calories', y='Saturated Fat', source = cds)
output_notebook()
show(p)
# Out:
#   <div class="bk-root" id="68043354-9075-407f-9a7b-fd1e1164e60c" data-root-id="1499"></div>

# %% [markdown]
# **Major and Minor Ticks**

# %%
p = figure(plot_width=400, plot_height=400, title='line graph',y_axis_label='Y axis', x_axis_label='X axis')

p.line(x='Calories', y='Saturated Fat', source = cds)
output_notebook()
p.axis.minor_tick_line_color = 'green'
p.axis.major_tick_line_color = 'red'
show(p)
# Out:
#   <div class="bk-root" id="d3eb5c78-b5b0-4e33-b81e-2c39110012b1" data-root-id="1633"></div>

# %% [markdown]
# **grid styles**

# %%
p = figure(plot_width=400, plot_height=400, title='line graph',y_axis_label='Y axis', x_axis_label='X axis')

p.line(x='Calories', y='Saturated Fat', source = cds)
p.grid.grid_line_color = 'navy'
p.grid.grid_line_alpha = 0.4

show(p)
# Out:
#   <div class="bk-root" id="52b32928-738f-410a-b74c-0aaacedc2ae6" data-root-id="1775"></div>
